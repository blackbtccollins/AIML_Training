# %% [markdown]
# <a href="https://colab.research.google.com/github/blackbtccollins/AIML_Training/blob/main/class/Blackburn_submissionv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fashion MNIST Competition! - Blackburn Submission
# **Author**: T. Blackburn
#
# **Updates**: New Version
#
# ## Problem
#
# Classify images from the "Fashion MNIST" data set.   Optimize the test accuracy.
#
# ## Metrics
#
# This competition is evaluated on the mean Dice coefficient. The Dice coefficient can be used to compare the pixel-wise agreement between a predicted segmentation and its corresponding ground truth. The formula is given by:![alt text](https://user-images.githubusercontent.com/26015273/41822460-2ca0a90a-77f0-11e8-9c71-7e88fa6b5c61.gif)
#
#
# The double sum is over the observations `i`, whose number is `N`, and the categories `c`, whose number is `C`. The term `1_{y_i \in C_c}` is the indicator function of the `i`th observation belonging to the `c`th category. The `p_{model}[y_i \in C_c]` is the probability predicted by the model for the `i`th observation to belong to the `c`th category. When there are more than two categories, the neural network outputs a vector of `C` probabilities, each giving the probability that the network input should be classified as belonging to the respective category. When the number of categories is just two, the neural network outputs a single probability `\hat{y}_i`, with the other one being `1` minus the output. This is why the binary cross entropy looks a bit different from categorical cross entropy, despite being a special case of it.
#
# ## Dataset
#
# This dataset is the Fashion MNIST dataset
#
# Recently, the researchers at Zalando, an e-commerce company, introduced Fashion MNIST as a drop-in replacement for the original MNIST dataset. Like MNIST, Fashion MNIST consists of a training set consisting of 60,000 examples belonging to 10 different classes and a test set of 10,000 examples. Each training example is a gray-scale image, 28x28 in size. The authors of the work further claim that the Fashion MNIST should actually replace MNIST dataset for benchmarking of new Machine Learning or Computer Vision models.
#
# Each image is 28 pixels in height and 28 pixels in width, for a total of 784 pixels in total. Each pixel has a single pixel-value associated with it, indicating the lightness or darkness of that pixel, with higher numbers meaning darker. This pixel-value is an integer between 0 and 255. The training and test data sets have 785 columns. The first column consists of the class labels (see above), and represents the article of clothing. The rest of the columns contain the pixel-values of the associated image.
#
# The Labels are:
# 0 T-shirt/top
# 1 Trouser
# 2 Pullover
# 3 Dress
# 4 Coat
# 5 Sandal
# 6 Shirt
# 7 Sneaker
# 8 Bag
# 9 Ankle boot
#
# ## Objective
#
# In this competition, you can try different variations of the CNN model given as a reference, you may evaluate techniques to squeeze more performance out of a CNN, or you might even try a completely different model, neural network or otherwise.  You will note that there are tips/tricks/techniques documented in many locations on the internet that could be useful.
#
# ## Rules and Timeline
#
# The primary measure for the competition will be the accuracy of prediction on the test data.  Ties will be broken by Precision accuracy first, then Recall Accuracy if needed.
#
# The results will be revealed at the end of the last day of class.  Please submit your Metrics blocks (Starts with SUBMIT... and ends with END SUBMISSION) to instructors (wtnewman@raytheon.com) before lunch.
#
# A prize will be given to the top finisher(s) based on the judgement of the instructor and the availability of prizes.

# %%
from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,  Conv2D, MaxPooling2D, Activation, BatchNormalization
from keras import backend as K
from keras.callbacks import EarlyStopping
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard,  ModelCheckpoint
from keras.layers.advanced_activations import LeakyReLU
import os
# %matplotlib inline
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "2"

# %% [markdown]
# ## Set Up Variables

# %%
epochs = 150                 # Number of Training Epochs
num_classes = 10            # This is the number of classes in the Fashion MNIST dataset
batch_size = 200          # This parameter can be adjusted
img_rows, img_cols = 28, 28 # Pixel sizes of the Images in the Dataset

# %% [markdown]
# ## Gather and Process Fashion MNIST data
#
# 1. First, collect the data from Keras (our goal is someday that our organizational data is this easy to get!)
# 2. Then split into train and test sets.
# 3. Next we need to process the data into the proper shape for the CNN
# 4. Then scale the floats to land between 0 and 1.  Often times we use sklearn's MinMaxScaler for this, but in this case we're going for simplicity.
# 5. Next take the y_train and y_test labels and encode them one-hot.  This will enable the CNN to function.

# %%
# Grab the data from the keras repository

mnist_data = fashion_mnist.load_data()
x = mnist_data[0][0]
y = mnist_data[0][1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=41)

# Process the date into the right tensor shape.  This is a good practice, but
# usually tensorflow uses channels last (the 'else' here)

if K.image_data_format() == "channels first":
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
    
#
#  Cast to a 32 bit float and then scale so the value is a float between 0 and 1
    
x_train = x_train.astype("float32")
x_test = x_test.astype("float32")
x_train /= 255
x_test /= 255

#
# Convert Class Vector to Binary Class Matrices (one-hot encoding).
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print(y_test.shape)

#
# Function to decode one-hot encoding later on when we want to evaluate performance.
def decode_one_hot(y):
    y_classes = [np.argmax(yi, axis=None, out=None) for yi in y]
    return y_classes

'''

Below we're experimenting with the Keras ImageDataGenerator.  From my experience, if these parameters
are set too aggressively, the loss/accuracy will either never improve or it will take too long to improve.
Below is an example of a complex data augmentation regime.  This is just for reference.  See my more simple
one at the bottom.

    
datagen = ImageDataGenerator(rotation_range=0.5, 
                                 zoom_range=0.1,
                                 featurewise_center=True,
                                 #featurewise_std_normalization=True,
                                 width_shift_range=0.1, 
                                 height_shift_range=0.1, 
                                 shear_range=0.1,
                                 horizontal_flip=True, 
                                 fill_mode="nearest")
'''
#
#  Set up our Image Augmentation Data Generator
#
datagen = ImageDataGenerator(rotation_range=5)
datagen.fit(x_train)
# Out:
# (19800, 10)

# %% [markdown]
# ## Build the Model
#
# * In this example, we define the below block as a Sequential Model.
# * See the excellent [Keras Documentation](https://keras.io/guides/sequential_model/) on Sequential Models for info.
# * Many of these parameters can be experimented with.  The documentation will help you understand how much to experiment.

# %%
#
# This is what is known as a Tensorflow (Keras) Sequential model
# We will talk at some level about each of these layer types in class.
#

###Best####

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 #kernel_initializer='he_normal',
                 input_shape=input_shape))
model.add(Dropout(0.6))
model.add(Activation('relu'))
model.add(Conv2D(64, kernel_size=(3,3)))
model.add(LeakyReLU(alpha=0.05))
model.add(Dropout(0.6))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(800))  
model.add(Activation('relu'))
model.add(Dropout(0.6))
model.add(Dense(num_classes, activation="softmax"))

my_callbacks = [ModelCheckpoint('model_out.hdf5', monitor='val_accuracy',  mode='max', save_best_only=True, period=1)]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
#
# This is what is known as a Tensorflow (Keras) Sequential model
# We will talk at some level about each of these layer types in class.
#

###BEST - Save ####

#model = Sequential()
#
#model.add(Conv2D(32, kernel_size=(3,3), input_shape=input_shape))
#model.add(Dropout(0.3))
#model.add(Activation('relu'))
#model.add(Conv2D(64, kernel_size=(3,3)))
#model.add(LeakyReLU(alpha=0.05))
#model.add(Dropout(0.2))
#model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Activation('relu'))
#model.add(Flatten())
#model.add(Dense(100))  
#model.add(Activation('relu'))
#model.add(Dropout(0.1))
#model.add(Dense(num_classes, activation="softmax"))
#
#my_callbacks = [ModelCheckpoint('model_out.hdf5', monitor='acc', save_best_only=True, period=1)]

# %% [markdown]
# ## Fit and Evaluate the Model

# %%
# Flag to determine whether we use Keras' Image augmentation data generator
augmentation = False

#
# Compile the model so we can fit it. Researching loss functions and optimizers
# might be a good thing to do.
#
model.compile(loss=keras.losses.categorical_crossentropy, 
              optimizer=keras.optimizers.Adam(), 
              metrics=['accuracy'])

if not augmentation:
    #
    # Fit the model.  Once the model is trained we'll evaluate the performance.
    print('not using image augmentation')
    hist = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=my_callbacks)
else:
# fits the model on batches with real-time data augmentation:
    hist = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                           steps_per_epoch=len(x_train) / batch_size, validation_data=(x_test, y_test),
                           epochs=epochs, verbose=1, callbacks=my_callbacks, workers = 2)


score = model.evaluate(x_test, y_test)

#
# Predict on the test data and pass to metrics function
yhat = np.argmax(model.predict(x_test), axis=-1)
y_dec = decode_one_hot(y_test)

print("\nSUBMIT THIS BLOCK for the Competition\n")
print(metrics.classification_report(y_dec, yhat))
print("Testing Loss:", score[0])
print("Testing Accuracy:", score[1])
print("END SUBMISSION BLOCK\n")

model.summary()
# Out:
# not using image augmentation
# Epoch 1/150
# 201/201 [==============================] - 5s 23ms/step - loss: 0.6252 - accuracy: 0.7728 - val_loss: 0.4967 - val_accuracy: 0.8564
# Epoch 2/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.4035 - accuracy: 0.8543 - val_loss: 0.4191 - val_accuracy: 0.8833
# Epoch 3/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.3506 - accuracy: 0.8718 - val_loss: 0.3619 - val_accuracy: 0.8885
# Epoch 4/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.3157 - accuracy: 0.8833 - val_loss: 0.3259 - val_accuracy: 0.8968
# Epoch 5/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.2931 - accuracy: 0.8921 - val_loss: 0.3282 - val_accuracy: 0.9053
# Epoch 6/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.2756 - accuracy: 0.8960 - val_loss: 0.2954 - val_accuracy: 0.9059
# Epoch 7/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.2573 - accuracy: 0.9041 - val_loss: 0.2764 - val_accuracy: 0.9109
# Epoch 8/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.2435 - accuracy: 0.9082 - val_loss: 0.2651 - val_accuracy: 0.9131
# Epoch 9/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.2290 - accuracy: 0.9148 - val_loss: 0.2534 - val_accuracy: 0.9174
# Epoch 10/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.2142 - accuracy: 0.9190 - val_loss: 0.2487 - val_accuracy: 0.9161
# Epoch 11/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.2096 - accuracy: 0.9203 - val_loss: 0.2544 - val_accuracy: 0.9144
# Epoch 12/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.2011 - accuracy: 0.9255 - val_loss: 0.2383 - val_accuracy: 0.9189
# Epoch 13/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1926 - accuracy: 0.9273 - val_loss: 0.2304 - val_accuracy: 0.9186
# Epoch 14/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1833 - accuracy: 0.9308 - val_loss: 0.2298 - val_accuracy: 0.9198
# Epoch 15/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1772 - accuracy: 0.9345 - val_loss: 0.2251 - val_accuracy: 0.9214
# Epoch 16/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1705 - accuracy: 0.9348 - val_loss: 0.2150 - val_accuracy: 0.9242
# Epoch 17/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1662 - accuracy: 0.9371 - val_loss: 0.2176 - val_accuracy: 0.9216
# Epoch 18/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1599 - accuracy: 0.9398 - val_loss: 0.2185 - val_accuracy: 0.9238
# Epoch 19/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1530 - accuracy: 0.9420 - val_loss: 0.2123 - val_accuracy: 0.9244
# Epoch 20/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1517 - accuracy: 0.9430 - val_loss: 0.2116 - val_accuracy: 0.9230
# Epoch 21/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1471 - accuracy: 0.9443 - val_loss: 0.2113 - val_accuracy: 0.9260
# Epoch 22/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1413 - accuracy: 0.9455 - val_loss: 0.2078 - val_accuracy: 0.9257
# Epoch 23/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1373 - accuracy: 0.9476 - val_loss: 0.2107 - val_accuracy: 0.9239
# Epoch 24/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1334 - accuracy: 0.9493 - val_loss: 0.2052 - val_accuracy: 0.9270
# Epoch 25/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1288 - accuracy: 0.9506 - val_loss: 0.2038 - val_accuracy: 0.9278
# Epoch 26/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1273 - accuracy: 0.9526 - val_loss: 0.2028 - val_accuracy: 0.9283
# Epoch 27/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1253 - accuracy: 0.9539 - val_loss: 0.2015 - val_accuracy: 0.9287
# Epoch 28/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1183 - accuracy: 0.9555 - val_loss: 0.2044 - val_accuracy: 0.9268
# Epoch 29/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1173 - accuracy: 0.9562 - val_loss: 0.2052 - val_accuracy: 0.9272
# Epoch 30/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1141 - accuracy: 0.9578 - val_loss: 0.2073 - val_accuracy: 0.9278
# Epoch 31/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1100 - accuracy: 0.9587 - val_loss: 0.2040 - val_accuracy: 0.9292
# Epoch 32/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1125 - accuracy: 0.9586 - val_loss: 0.2117 - val_accuracy: 0.9247
# Epoch 33/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1034 - accuracy: 0.9606 - val_loss: 0.2039 - val_accuracy: 0.9281
# Epoch 34/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1069 - accuracy: 0.9595 - val_loss: 0.2086 - val_accuracy: 0.9276
# Epoch 35/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1018 - accuracy: 0.9618 - val_loss: 0.2080 - val_accuracy: 0.9279
# Epoch 36/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1014 - accuracy: 0.9608 - val_loss: 0.2047 - val_accuracy: 0.9289
# Epoch 37/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1005 - accuracy: 0.9623 - val_loss: 0.2041 - val_accuracy: 0.9293
# Epoch 38/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0961 - accuracy: 0.9646 - val_loss: 0.2099 - val_accuracy: 0.9288
# Epoch 39/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0953 - accuracy: 0.9641 - val_loss: 0.2100 - val_accuracy: 0.9280
# Epoch 40/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0949 - accuracy: 0.9644 - val_loss: 0.2071 - val_accuracy: 0.9291
# Epoch 41/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0901 - accuracy: 0.9660 - val_loss: 0.2021 - val_accuracy: 0.9310
# Epoch 42/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0882 - accuracy: 0.9680 - val_loss: 0.2070 - val_accuracy: 0.9293
# Epoch 43/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0884 - accuracy: 0.9675 - val_loss: 0.2112 - val_accuracy: 0.9282
# Epoch 44/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0860 - accuracy: 0.9685 - val_loss: 0.2091 - val_accuracy: 0.9275
# Epoch 45/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0853 - accuracy: 0.9683 - val_loss: 0.2130 - val_accuracy: 0.9275
# Epoch 46/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0853 - accuracy: 0.9668 - val_loss: 0.2133 - val_accuracy: 0.9282
# Epoch 47/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0794 - accuracy: 0.9703 - val_loss: 0.2107 - val_accuracy: 0.9287
# Epoch 48/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0814 - accuracy: 0.9694 - val_loss: 0.2154 - val_accuracy: 0.9277
# Epoch 49/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0813 - accuracy: 0.9693 - val_loss: 0.2071 - val_accuracy: 0.9318
# Epoch 50/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0786 - accuracy: 0.9709 - val_loss: 0.2109 - val_accuracy: 0.9292
# Epoch 51/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0809 - accuracy: 0.9691 - val_loss: 0.2167 - val_accuracy: 0.9301
# Epoch 52/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0766 - accuracy: 0.9713 - val_loss: 0.2055 - val_accuracy: 0.9314
# Epoch 53/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0730 - accuracy: 0.9729 - val_loss: 0.2104 - val_accuracy: 0.9296
# Epoch 54/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0770 - accuracy: 0.9704 - val_loss: 0.2127 - val_accuracy: 0.9295
# Epoch 55/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0792 - accuracy: 0.9710 - val_loss: 0.2100 - val_accuracy: 0.9295
# Epoch 56/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0703 - accuracy: 0.9741 - val_loss: 0.2220 - val_accuracy: 0.9280
# Epoch 57/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0771 - accuracy: 0.9710 - val_loss: 0.2142 - val_accuracy: 0.9284
# Epoch 58/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0720 - accuracy: 0.9726 - val_loss: 0.2213 - val_accuracy: 0.9271
# Epoch 59/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0709 - accuracy: 0.9736 - val_loss: 0.2216 - val_accuracy: 0.9287
# Epoch 60/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0726 - accuracy: 0.9741 - val_loss: 0.2187 - val_accuracy: 0.9286
# Epoch 61/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0693 - accuracy: 0.9745 - val_loss: 0.2169 - val_accuracy: 0.9299
# Epoch 62/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0716 - accuracy: 0.9733 - val_loss: 0.2154 - val_accuracy: 0.9328
# Epoch 63/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0729 - accuracy: 0.9724 - val_loss: 0.2146 - val_accuracy: 0.9309
# Epoch 64/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0712 - accuracy: 0.9736 - val_loss: 0.2246 - val_accuracy: 0.9305
# Epoch 65/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0664 - accuracy: 0.9757 - val_loss: 0.2171 - val_accuracy: 0.9317
# Epoch 66/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0743 - accuracy: 0.9716 - val_loss: 0.2179 - val_accuracy: 0.9307
# Epoch 67/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0691 - accuracy: 0.9743 - val_loss: 0.2179 - val_accuracy: 0.9316
# Epoch 68/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0666 - accuracy: 0.9750 - val_loss: 0.2118 - val_accuracy: 0.9327
# Epoch 69/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0683 - accuracy: 0.9749 - val_loss: 0.2175 - val_accuracy: 0.9317
# Epoch 70/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0676 - accuracy: 0.9753 - val_loss: 0.2206 - val_accuracy: 0.9303
# Epoch 71/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0681 - accuracy: 0.9752 - val_loss: 0.2194 - val_accuracy: 0.9301
# Epoch 72/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0635 - accuracy: 0.9761 - val_loss: 0.2267 - val_accuracy: 0.9292
# Epoch 73/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0628 - accuracy: 0.9766 - val_loss: 0.2166 - val_accuracy: 0.9305
# Epoch 74/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0625 - accuracy: 0.9775 - val_loss: 0.2245 - val_accuracy: 0.9307
# Epoch 75/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0614 - accuracy: 0.9781 - val_loss: 0.2336 - val_accuracy: 0.9285
# Epoch 76/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0629 - accuracy: 0.9771 - val_loss: 0.2235 - val_accuracy: 0.9301
# Epoch 77/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0618 - accuracy: 0.9779 - val_loss: 0.2284 - val_accuracy: 0.9312
# Epoch 78/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0632 - accuracy: 0.9769 - val_loss: 0.2199 - val_accuracy: 0.9322
# Epoch 79/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0623 - accuracy: 0.9776 - val_loss: 0.2256 - val_accuracy: 0.9309
# Epoch 80/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0635 - accuracy: 0.9769 - val_loss: 0.2196 - val_accuracy: 0.9324
# Epoch 81/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0610 - accuracy: 0.9784 - val_loss: 0.2260 - val_accuracy: 0.9312
# Epoch 82/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0589 - accuracy: 0.9780 - val_loss: 0.2230 - val_accuracy: 0.9317
# Epoch 83/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0588 - accuracy: 0.9786 - val_loss: 0.2399 - val_accuracy: 0.9299
# Epoch 84/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0570 - accuracy: 0.9792 - val_loss: 0.2227 - val_accuracy: 0.9335
# Epoch 85/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0626 - accuracy: 0.9769 - val_loss: 0.2283 - val_accuracy: 0.9302
# Epoch 86/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0599 - accuracy: 0.9780 - val_loss: 0.2345 - val_accuracy: 0.9277
# Epoch 87/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0587 - accuracy: 0.9785 - val_loss: 0.2330 - val_accuracy: 0.9315
# Epoch 88/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0608 - accuracy: 0.9787 - val_loss: 0.2271 - val_accuracy: 0.9309
# Epoch 89/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0601 - accuracy: 0.9783 - val_loss: 0.2390 - val_accuracy: 0.9308
# Epoch 90/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0574 - accuracy: 0.9798 - val_loss: 0.2287 - val_accuracy: 0.9318
# Epoch 91/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0567 - accuracy: 0.9799 - val_loss: 0.2292 - val_accuracy: 0.9315
# Epoch 92/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0574 - accuracy: 0.9785 - val_loss: 0.2434 - val_accuracy: 0.9295
# Epoch 93/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0534 - accuracy: 0.9812 - val_loss: 0.2398 - val_accuracy: 0.9290
# Epoch 94/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0561 - accuracy: 0.9799 - val_loss: 0.2318 - val_accuracy: 0.9309
# Epoch 95/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0581 - accuracy: 0.9791 - val_loss: 0.2293 - val_accuracy: 0.9322
# Epoch 96/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0520 - accuracy: 0.9818 - val_loss: 0.2324 - val_accuracy: 0.9327
# Epoch 97/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0599 - accuracy: 0.9788 - val_loss: 0.2384 - val_accuracy: 0.9305
# Epoch 98/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0530 - accuracy: 0.9806 - val_loss: 0.2343 - val_accuracy: 0.9304
# Epoch 99/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0555 - accuracy: 0.9794 - val_loss: 0.2385 - val_accuracy: 0.9294
# Epoch 100/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0552 - accuracy: 0.9800 - val_loss: 0.2435 - val_accuracy: 0.9289
# Epoch 101/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0554 - accuracy: 0.9808 - val_loss: 0.2360 - val_accuracy: 0.9321
# Epoch 102/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0535 - accuracy: 0.9807 - val_loss: 0.2374 - val_accuracy: 0.9310
# Epoch 103/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0544 - accuracy: 0.9807 - val_loss: 0.2426 - val_accuracy: 0.9292
# Epoch 104/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0497 - accuracy: 0.9821 - val_loss: 0.2335 - val_accuracy: 0.9314
# Epoch 105/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0506 - accuracy: 0.9821 - val_loss: 0.2525 - val_accuracy: 0.9294
# Epoch 106/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0544 - accuracy: 0.9811 - val_loss: 0.2448 - val_accuracy: 0.9299
# Epoch 107/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0513 - accuracy: 0.9817 - val_loss: 0.2454 - val_accuracy: 0.9313
# Epoch 108/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0528 - accuracy: 0.9817 - val_loss: 0.2324 - val_accuracy: 0.9308
# Epoch 109/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0563 - accuracy: 0.9790 - val_loss: 0.2436 - val_accuracy: 0.9297
# Epoch 110/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0535 - accuracy: 0.9813 - val_loss: 0.2499 - val_accuracy: 0.9306
# Epoch 111/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0522 - accuracy: 0.9818 - val_loss: 0.2339 - val_accuracy: 0.9298
# Epoch 112/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0517 - accuracy: 0.9818 - val_loss: 0.2530 - val_accuracy: 0.9299
# Epoch 113/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0488 - accuracy: 0.9826 - val_loss: 0.2418 - val_accuracy: 0.9304
# Epoch 114/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0534 - accuracy: 0.9807 - val_loss: 0.2375 - val_accuracy: 0.9309
# Epoch 115/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0510 - accuracy: 0.9822 - val_loss: 0.2497 - val_accuracy: 0.9299
# Epoch 116/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0512 - accuracy: 0.9822 - val_loss: 0.2405 - val_accuracy: 0.9304
# Epoch 117/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0504 - accuracy: 0.9816 - val_loss: 0.2482 - val_accuracy: 0.9306
# Epoch 118/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0511 - accuracy: 0.9815 - val_loss: 0.2460 - val_accuracy: 0.9307
# Epoch 119/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0516 - accuracy: 0.9808 - val_loss: 0.2515 - val_accuracy: 0.9292
# Epoch 120/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0545 - accuracy: 0.9803 - val_loss: 0.2425 - val_accuracy: 0.9307
# Epoch 121/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0486 - accuracy: 0.9830 - val_loss: 0.2502 - val_accuracy: 0.9314
# Epoch 122/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0495 - accuracy: 0.9822 - val_loss: 0.2547 - val_accuracy: 0.9324
# Epoch 123/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0498 - accuracy: 0.9826 - val_loss: 0.2422 - val_accuracy: 0.9316
# Epoch 124/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0478 - accuracy: 0.9833 - val_loss: 0.2511 - val_accuracy: 0.9318
# Epoch 125/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0462 - accuracy: 0.9844 - val_loss: 0.2516 - val_accuracy: 0.9311
# Epoch 126/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0494 - accuracy: 0.9826 - val_loss: 0.2499 - val_accuracy: 0.9302
# Epoch 127/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0463 - accuracy: 0.9836 - val_loss: 0.2523 - val_accuracy: 0.9306
# Epoch 128/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0481 - accuracy: 0.9828 - val_loss: 0.2575 - val_accuracy: 0.9322
# Epoch 129/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0542 - accuracy: 0.9805 - val_loss: 0.2513 - val_accuracy: 0.9317
# Epoch 130/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.2558 - val_accuracy: 0.9326
# Epoch 131/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0514 - accuracy: 0.9820 - val_loss: 0.2572 - val_accuracy: 0.9292
# Epoch 132/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0580 - accuracy: 0.9800 - val_loss: 0.2497 - val_accuracy: 0.9288
# Epoch 133/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0516 - accuracy: 0.9813 - val_loss: 0.2439 - val_accuracy: 0.9306
# Epoch 134/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0466 - accuracy: 0.9832 - val_loss: 0.2640 - val_accuracy: 0.9313
# Epoch 135/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0463 - accuracy: 0.9841 - val_loss: 0.2537 - val_accuracy: 0.9302
# Epoch 136/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0416 - accuracy: 0.9852 - val_loss: 0.2600 - val_accuracy: 0.9310
# Epoch 137/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0509 - accuracy: 0.9829 - val_loss: 0.2427 - val_accuracy: 0.9325
# Epoch 138/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0480 - accuracy: 0.9825 - val_loss: 0.2528 - val_accuracy: 0.9342
# Epoch 139/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0480 - accuracy: 0.9830 - val_loss: 0.2596 - val_accuracy: 0.9295
# Epoch 140/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0475 - accuracy: 0.9838 - val_loss: 0.2614 - val_accuracy: 0.9311
# Epoch 141/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0449 - accuracy: 0.9839 - val_loss: 0.2594 - val_accuracy: 0.9309
# Epoch 142/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0484 - accuracy: 0.9828 - val_loss: 0.2646 - val_accuracy: 0.9287
# Epoch 143/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0471 - accuracy: 0.9840 - val_loss: 0.2517 - val_accuracy: 0.9315
# Epoch 144/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0487 - accuracy: 0.9833 - val_loss: 0.2443 - val_accuracy: 0.9325
# Epoch 145/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0495 - accuracy: 0.9828 - val_loss: 0.2556 - val_accuracy: 0.9314
# Epoch 146/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0492 - accuracy: 0.9830 - val_loss: 0.2491 - val_accuracy: 0.9332
# Epoch 147/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0476 - accuracy: 0.9837 - val_loss: 0.2529 - val_accuracy: 0.9314
# Epoch 148/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0464 - accuracy: 0.9840 - val_loss: 0.2553 - val_accuracy: 0.9301
# Epoch 149/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0461 - accuracy: 0.9843 - val_loss: 0.2585 - val_accuracy: 0.9299
# Epoch 150/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0437 - accuracy: 0.9845 - val_loss: 0.2598 - val_accuracy: 0.9320
# 619/619 [==============================] - 3s 4ms/step - loss: 0.2598 - accuracy: 0.9320
#
# SUBMIT THIS BLOCK for the Competition
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      2051
#            1       0.99      0.99      0.99      1956
#            2       0.89      0.90      0.90      2013
#            3       0.92      0.94      0.93      2008
#            4       0.92      0.88      0.90      2031
#            5       0.99      0.99      0.99      1923
#            6       0.79      0.82      0.80      1952
#            7       0.96      0.98      0.97      1920
#            8       0.99      0.98      0.99      1911
#            9       0.98      0.97      0.97      2035
#
#     accuracy                           0.93     19800
#    macro avg       0.93      0.93      0.93     19800
# weighted avg       0.93      0.93      0.93     19800
#
# Testing Loss: 0.25981342792510986
# Testing Accuracy: 0.9319697022438049
# END SUBMISSION BLOCK
#
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_94 (Conv2D)          (None, 26, 26, 32)        320
#
#  dropout_141 (Dropout)       (None, 26, 26, 32)        0
#
#  activation_141 (Activation)  (None, 26, 26, 32)       0
#
#  conv2d_95 (Conv2D)          (None, 24, 24, 64)        18496
#
#  leaky_re_lu_47 (LeakyReLU)  (None, 24, 24, 64)        0
#
#  dropout_142 (Dropout)       (None, 24, 24, 64)        0
#
#  max_pooling2d_47 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  activation_142 (Activation)  (None, 12, 12, 64)       0
#
#  flatten_47 (Flatten)        (None, 9216)              0
#
#  dense_94 (Dense)            (None, 800)               7373600
#
#  activation_143 (Activation)  (None, 800)              0
#
#  dropout_143 (Dropout)       (None, 800)               0
#
#  dense_95 (Dense)            (None, 10)                8010
#
# =================================================================
# Total params: 7,400,426
# Trainable params: 7,400,426
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Plot the accuracy vs. validation accuracy

# %%
epoch_list = list(range(1, len(hist.history['accuracy']) + 1))
plt.plot(epoch_list, hist.history['accuracy'], epoch_list, hist.history['val_accuracy'])
plt.legend(("Training Accuracy - Best", "Validation Accuracy - Best"))
plt.show()

plt.plot(epoch_list, hist.history['loss'], epoch_list, hist.history['val_loss'])
plt.legend(("Training Loss - Best", "Validation Loss - Best"))
plt.show()

# %% [markdown]
# ## Extra Test Section

# %%
#
# This is what is known as a Tensorflow (Keras) Sequential model
# We will talk at some level about each of these layer types in class.
#

###Test####

model_1 = Sequential()
model_1.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 #kernel_initializer='he_normal',
                 input_shape=input_shape))
model_1.add(Dropout(0.7))
model_1.add(Activation('relu'))
model_1.add(Conv2D(64, kernel_size=(3,3)))
model_1.add(LeakyReLU(alpha=0.05))
model_1.add(Dropout(0.7))
model_1.add(MaxPooling2D(pool_size=(2,2)))
model_1.add(Activation('relu'))
model_1.add(Flatten())
model_1.add(Dense(800))  
model_1.add(Activation('relu'))
model_1.add(Dropout(0.7))
model_1.add(Dense(num_classes, activation="softmax"))

my_callbacks_1 = [ModelCheckpoint('model_out.hdf5', monitor='val_accuracy',  mode='max', save_best_only=True, period=1)]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Flag to determine whether we use Keras' Image augmentation data generator
augmentation = False

#
# Compile the model so we can fit it. Researching loss functions and optimizers
# might be a good thing to do.
#
model_1.compile(loss=keras.losses.categorical_crossentropy, 
              optimizer=keras.optimizers.Adam(), 
              metrics=['accuracy'])

if not augmentation:
    #
    # Fit the model.  Once the model is trained we'll evaluate the performance.
    print('not using image augmentation')
    hist1 = model_1.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=my_callbacks_1)
else:
# fits the model on batches with real-time data augmentation:
    hist1 = model_1.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                           steps_per_epoch=len(x_train) / batch_size, validation_data=(x_test, y_test),
                           epochs=epochs, verbose=1, callbacks=my_callbacks_1, workers = 2)


score_1 = model_1.evaluate(x_test, y_test)

#
# Predict on the test data and pass to metrics function
yhat = np.argmax(model_1.predict(x_test), axis=-1)
y_dec = decode_one_hot(y_test)

print("\nSUBMIT THIS BLOCK for the Competition\n")
print(metrics.classification_report(y_dec, yhat))
print("Testing Loss:", score_1[0])
print("Testing Accuracy:", score_1[1])
print("END SUBMISSION BLOCK\n")

model_1.summary()
# Out:
# not using image augmentation
# Epoch 1/150
# 201/201 [==============================] - 5s 23ms/step - loss: 0.5854 - accuracy: 0.7878 - val_loss: 0.5211 - val_accuracy: 0.8606
# Epoch 2/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.3648 - accuracy: 0.8682 - val_loss: 0.3783 - val_accuracy: 0.8862
# Epoch 3/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.3126 - accuracy: 0.8847 - val_loss: 0.3294 - val_accuracy: 0.8959
# Epoch 4/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.2850 - accuracy: 0.8945 - val_loss: 0.3254 - val_accuracy: 0.8971
# Epoch 5/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.2567 - accuracy: 0.9056 - val_loss: 0.2713 - val_accuracy: 0.9101
# Epoch 6/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.2379 - accuracy: 0.9104 - val_loss: 0.2610 - val_accuracy: 0.9120
# Epoch 7/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.2207 - accuracy: 0.9177 - val_loss: 0.2658 - val_accuracy: 0.9101
# Epoch 8/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.2065 - accuracy: 0.9222 - val_loss: 0.2470 - val_accuracy: 0.9182
# Epoch 9/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1933 - accuracy: 0.9267 - val_loss: 0.2356 - val_accuracy: 0.9173
# Epoch 10/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1771 - accuracy: 0.9329 - val_loss: 0.2323 - val_accuracy: 0.9210
# Epoch 11/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1656 - accuracy: 0.9383 - val_loss: 0.2261 - val_accuracy: 0.9205
# Epoch 12/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1582 - accuracy: 0.9405 - val_loss: 0.2246 - val_accuracy: 0.9203
# Epoch 13/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1489 - accuracy: 0.9442 - val_loss: 0.2198 - val_accuracy: 0.9235
# Epoch 14/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1369 - accuracy: 0.9478 - val_loss: 0.2154 - val_accuracy: 0.9246
# Epoch 15/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1326 - accuracy: 0.9510 - val_loss: 0.2138 - val_accuracy: 0.9235
# Epoch 16/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.1244 - accuracy: 0.9522 - val_loss: 0.2129 - val_accuracy: 0.9254
# Epoch 17/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1192 - accuracy: 0.9548 - val_loss: 0.2229 - val_accuracy: 0.9199
# Epoch 18/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.1092 - accuracy: 0.9594 - val_loss: 0.2134 - val_accuracy: 0.9246
# Epoch 19/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.1022 - accuracy: 0.9617 - val_loss: 0.2194 - val_accuracy: 0.9238
# Epoch 20/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0970 - accuracy: 0.9643 - val_loss: 0.2088 - val_accuracy: 0.9272
# Epoch 21/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0914 - accuracy: 0.9661 - val_loss: 0.2119 - val_accuracy: 0.9266
# Epoch 22/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0890 - accuracy: 0.9667 - val_loss: 0.2133 - val_accuracy: 0.9275
# Epoch 23/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0855 - accuracy: 0.9683 - val_loss: 0.2170 - val_accuracy: 0.9269
# Epoch 24/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0807 - accuracy: 0.9701 - val_loss: 0.2151 - val_accuracy: 0.9278
# Epoch 25/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0771 - accuracy: 0.9711 - val_loss: 0.2190 - val_accuracy: 0.9259
# Epoch 26/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0745 - accuracy: 0.9718 - val_loss: 0.2211 - val_accuracy: 0.9253
# Epoch 27/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0707 - accuracy: 0.9739 - val_loss: 0.2280 - val_accuracy: 0.9269
# Epoch 28/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0671 - accuracy: 0.9747 - val_loss: 0.2262 - val_accuracy: 0.9268
# Epoch 29/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0659 - accuracy: 0.9758 - val_loss: 0.2283 - val_accuracy: 0.9250
# Epoch 30/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0623 - accuracy: 0.9770 - val_loss: 0.2244 - val_accuracy: 0.9292
# Epoch 31/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0635 - accuracy: 0.9762 - val_loss: 0.2354 - val_accuracy: 0.9251
# Epoch 32/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0606 - accuracy: 0.9778 - val_loss: 0.2287 - val_accuracy: 0.9276
# Epoch 33/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0568 - accuracy: 0.9786 - val_loss: 0.2353 - val_accuracy: 0.9262
# Epoch 34/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0545 - accuracy: 0.9805 - val_loss: 0.2417 - val_accuracy: 0.9285
# Epoch 35/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0526 - accuracy: 0.9801 - val_loss: 0.2422 - val_accuracy: 0.9264
# Epoch 36/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0528 - accuracy: 0.9804 - val_loss: 0.2374 - val_accuracy: 0.9274
# Epoch 37/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0511 - accuracy: 0.9814 - val_loss: 0.2294 - val_accuracy: 0.9289
# Epoch 38/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0516 - accuracy: 0.9807 - val_loss: 0.2358 - val_accuracy: 0.9278
# Epoch 39/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0501 - accuracy: 0.9813 - val_loss: 0.2404 - val_accuracy: 0.9285
# Epoch 40/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0469 - accuracy: 0.9825 - val_loss: 0.2460 - val_accuracy: 0.9290
# Epoch 41/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0471 - accuracy: 0.9829 - val_loss: 0.2482 - val_accuracy: 0.9284
# Epoch 42/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0433 - accuracy: 0.9834 - val_loss: 0.2463 - val_accuracy: 0.9276
# Epoch 43/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0477 - accuracy: 0.9829 - val_loss: 0.2489 - val_accuracy: 0.9279
# Epoch 44/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0425 - accuracy: 0.9844 - val_loss: 0.2463 - val_accuracy: 0.9304
# Epoch 45/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0404 - accuracy: 0.9858 - val_loss: 0.2741 - val_accuracy: 0.9263
# Epoch 46/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0454 - accuracy: 0.9837 - val_loss: 0.2493 - val_accuracy: 0.9289
# Epoch 47/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0398 - accuracy: 0.9858 - val_loss: 0.2543 - val_accuracy: 0.9304
# Epoch 48/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0384 - accuracy: 0.9856 - val_loss: 0.2632 - val_accuracy: 0.9286
# Epoch 49/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0403 - accuracy: 0.9854 - val_loss: 0.2619 - val_accuracy: 0.9266
# Epoch 50/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0401 - accuracy: 0.9858 - val_loss: 0.2662 - val_accuracy: 0.9281
# Epoch 51/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0397 - accuracy: 0.9856 - val_loss: 0.2616 - val_accuracy: 0.9274
# Epoch 52/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0384 - accuracy: 0.9852 - val_loss: 0.2544 - val_accuracy: 0.9279
# Epoch 53/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0389 - accuracy: 0.9858 - val_loss: 0.2520 - val_accuracy: 0.9294
# Epoch 54/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0380 - accuracy: 0.9869 - val_loss: 0.2612 - val_accuracy: 0.9270
# Epoch 55/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0364 - accuracy: 0.9866 - val_loss: 0.2606 - val_accuracy: 0.9285
# Epoch 56/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0311 - accuracy: 0.9891 - val_loss: 0.2839 - val_accuracy: 0.9294
# Epoch 57/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0384 - accuracy: 0.9860 - val_loss: 0.2801 - val_accuracy: 0.9294
# Epoch 58/150
# 201/201 [==============================] - 4s 22ms/step - loss: 0.0399 - accuracy: 0.9857 - val_loss: 0.2538 - val_accuracy: 0.9320
# Epoch 59/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0361 - accuracy: 0.9867 - val_loss: 0.2711 - val_accuracy: 0.9299
# Epoch 60/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0348 - accuracy: 0.9870 - val_loss: 0.2745 - val_accuracy: 0.9269
# Epoch 61/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0330 - accuracy: 0.9883 - val_loss: 0.2796 - val_accuracy: 0.9275
# Epoch 62/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0327 - accuracy: 0.9882 - val_loss: 0.2730 - val_accuracy: 0.9278
# Epoch 63/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0335 - accuracy: 0.9876 - val_loss: 0.2772 - val_accuracy: 0.9286
# Epoch 64/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0316 - accuracy: 0.9891 - val_loss: 0.2736 - val_accuracy: 0.9296
# Epoch 65/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0318 - accuracy: 0.9884 - val_loss: 0.3003 - val_accuracy: 0.9264
# Epoch 66/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0315 - accuracy: 0.9887 - val_loss: 0.2758 - val_accuracy: 0.9277
# Epoch 67/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0307 - accuracy: 0.9890 - val_loss: 0.2802 - val_accuracy: 0.9291
# Epoch 68/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0331 - accuracy: 0.9883 - val_loss: 0.2926 - val_accuracy: 0.9279
# Epoch 69/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0324 - accuracy: 0.9883 - val_loss: 0.2870 - val_accuracy: 0.9290
# Epoch 70/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0311 - accuracy: 0.9890 - val_loss: 0.2819 - val_accuracy: 0.9267
# Epoch 71/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0304 - accuracy: 0.9894 - val_loss: 0.2776 - val_accuracy: 0.9289
# Epoch 72/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.2815 - val_accuracy: 0.9293
# Epoch 73/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0287 - accuracy: 0.9902 - val_loss: 0.2794 - val_accuracy: 0.9302
# Epoch 74/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0298 - accuracy: 0.9896 - val_loss: 0.2955 - val_accuracy: 0.9282
# Epoch 75/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0307 - accuracy: 0.9894 - val_loss: 0.3052 - val_accuracy: 0.9278
# Epoch 76/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0315 - accuracy: 0.9891 - val_loss: 0.2883 - val_accuracy: 0.9297
# Epoch 77/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0321 - accuracy: 0.9884 - val_loss: 0.2910 - val_accuracy: 0.9287
# Epoch 78/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0273 - accuracy: 0.9902 - val_loss: 0.2977 - val_accuracy: 0.9277
# Epoch 79/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0259 - accuracy: 0.9907 - val_loss: 0.3077 - val_accuracy: 0.9286
# Epoch 80/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0297 - accuracy: 0.9897 - val_loss: 0.2987 - val_accuracy: 0.9286
# Epoch 81/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0248 - accuracy: 0.9915 - val_loss: 0.3092 - val_accuracy: 0.9287
# Epoch 82/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0282 - accuracy: 0.9904 - val_loss: 0.3007 - val_accuracy: 0.9270
# Epoch 83/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0300 - accuracy: 0.9896 - val_loss: 0.3040 - val_accuracy: 0.9268
# Epoch 84/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0286 - accuracy: 0.9904 - val_loss: 0.3078 - val_accuracy: 0.9286
# Epoch 85/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.3037 - val_accuracy: 0.9301
# Epoch 86/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.3044 - val_accuracy: 0.9292
# Epoch 87/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0276 - accuracy: 0.9903 - val_loss: 0.3109 - val_accuracy: 0.9285
# Epoch 88/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0282 - accuracy: 0.9905 - val_loss: 0.3012 - val_accuracy: 0.9293
# Epoch 89/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0272 - accuracy: 0.9905 - val_loss: 0.2999 - val_accuracy: 0.9290
# Epoch 90/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0284 - accuracy: 0.9902 - val_loss: 0.3062 - val_accuracy: 0.9296
# Epoch 91/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0292 - accuracy: 0.9905 - val_loss: 0.3000 - val_accuracy: 0.9284
# Epoch 92/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.2826 - val_accuracy: 0.9298
# Epoch 93/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0261 - accuracy: 0.9905 - val_loss: 0.3171 - val_accuracy: 0.9273
# Epoch 94/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0275 - accuracy: 0.9902 - val_loss: 0.3145 - val_accuracy: 0.9303
# Epoch 95/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0244 - accuracy: 0.9915 - val_loss: 0.2968 - val_accuracy: 0.9307
# Epoch 96/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0257 - accuracy: 0.9909 - val_loss: 0.3181 - val_accuracy: 0.9295
# Epoch 97/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0276 - accuracy: 0.9903 - val_loss: 0.3256 - val_accuracy: 0.9298
# Epoch 98/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0260 - accuracy: 0.9910 - val_loss: 0.3254 - val_accuracy: 0.9283
# Epoch 99/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0276 - accuracy: 0.9906 - val_loss: 0.3156 - val_accuracy: 0.9277
# Epoch 100/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 0.3202 - val_accuracy: 0.9287
# Epoch 101/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 0.3275 - val_accuracy: 0.9294
# Epoch 102/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0270 - accuracy: 0.9907 - val_loss: 0.3222 - val_accuracy: 0.9293
# Epoch 103/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0257 - accuracy: 0.9915 - val_loss: 0.2989 - val_accuracy: 0.9293
# Epoch 104/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0246 - accuracy: 0.9916 - val_loss: 0.3195 - val_accuracy: 0.9283
# Epoch 105/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0252 - accuracy: 0.9910 - val_loss: 0.3236 - val_accuracy: 0.9275
# Epoch 106/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0246 - accuracy: 0.9914 - val_loss: 0.3249 - val_accuracy: 0.9289
# Epoch 107/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0242 - accuracy: 0.9914 - val_loss: 0.3325 - val_accuracy: 0.9264
# Epoch 108/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0287 - accuracy: 0.9906 - val_loss: 0.3374 - val_accuracy: 0.9259
# Epoch 109/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.3012 - val_accuracy: 0.9287
# Epoch 110/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0252 - accuracy: 0.9912 - val_loss: 0.3339 - val_accuracy: 0.9274
# Epoch 111/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.3336 - val_accuracy: 0.9280
# Epoch 112/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.3296 - val_accuracy: 0.9284
# Epoch 113/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0227 - accuracy: 0.9923 - val_loss: 0.3409 - val_accuracy: 0.9285
# Epoch 114/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 0.3267 - val_accuracy: 0.9300
# Epoch 115/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.3347 - val_accuracy: 0.9297
# Epoch 116/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0249 - accuracy: 0.9914 - val_loss: 0.3351 - val_accuracy: 0.9298
# Epoch 117/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.3289 - val_accuracy: 0.9299
# Epoch 118/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 0.3286 - val_accuracy: 0.9254
# Epoch 119/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.3455 - val_accuracy: 0.9273
# Epoch 120/150
# 201/201 [==============================] - 4s 21ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 0.3454 - val_accuracy: 0.9289
# Epoch 121/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0270 - accuracy: 0.9907 - val_loss: 0.3257 - val_accuracy: 0.9297
# Epoch 122/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0239 - accuracy: 0.9920 - val_loss: 0.3376 - val_accuracy: 0.9291
# Epoch 123/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0255 - accuracy: 0.9914 - val_loss: 0.3204 - val_accuracy: 0.9281
# Epoch 124/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.3431 - val_accuracy: 0.9290
# Epoch 125/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.3506 - val_accuracy: 0.9297
# Epoch 126/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.3431 - val_accuracy: 0.9307
# Epoch 127/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 0.3543 - val_accuracy: 0.9280
# Epoch 128/150
# 201/201 [==============================] - 4s 20ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.3455 - val_accuracy: 0.9307
# Epoch 129/150
# 187/201 [==========================>...] - ETA: 0s - loss: 0.0232 - accuracy: 0.9920

# %%
epoch_list_1 = list(range(1, len(hist1.history['accuracy']) + 1))
plt.plot(epoch_list_1, hist1.history['accuracy'], epoch_list_1, hist1.history['val_accuracy'])
plt.legend(("Training Accuracy - Test", "Validation Accuracy - Test"))
plt.show()

plt.plot(epoch_list_1, hist1.history['loss'], epoch_list_1, hist1.history['val_loss'])
plt.legend(("Training Loss - Test", "Validation Loss - Test"))
plt.show()

# %%
#Compare

plt.plot(epoch_list, hist.history['accuracy'], epoch_list, hist.history['val_accuracy'])
plt.plot(epoch_list_1, hist1.history['accuracy'], epoch_list_1, hist1.history['val_accuracy'])
plt.legend(("Training Accuracy - Best", "Validation Accuracy - Best", "Training Accuracy - Test", "Validation Accuracy - Test"))
plt.show()

#plt.plot(epoch_list_1, hist1.history['loss'], epoch_list_1, hist1.history['val_loss'])
#plt.legend(("Training Loss - Test", "Validation Loss - Test"))
#plt.show()


print("Testing Accuracy - Best:", score[1])
print("Testing Accuracy - Test:", score_1[1])
# Out:
# Testing Accuracy - Best: 0.9314141273498535
# Testing Accuracy - Test: 0.9272727370262146

# %% [markdown]
# ## Visualization of Performance on the Test Set
#
# Here is a visualization of how well our classifier can do inference.

# %%
import cv2
from imutils import build_montages
from google.colab.patches import cv2_imshow

# initialize our list of output images
images = []

labelNames = ["top", "trouser", "pullover", "dress", "coat",
	"sandal", "shirt", "sneaker", "bag", "ankle boot"]
 
# randomly select a few testing fashion items
for i in np.random.choice(np.arange(0, len(y_test)), size=(16,)):
	# classify the clothing
	probs = model.predict(x_test[np.newaxis, i])
	prediction = probs.argmax(axis=1)
	label = labelNames[prediction[0]]
 
	# extract the image from the testData if using "channels_first"
	# ordering
	if K.image_data_format() == "channels_first":
		image = (x_test[i][0] * 255).astype("uint8")
 
	# otherwise we are using "channels_last" ordering
	else:
		image = (x_test[i] * 255).astype("uint8")
    # initialize the text label color as green (correct)
	color = (0, 255, 0)
 
	# otherwise, the class label prediction is incorrect
	if prediction[0] != np.argmax(y_test[i]):
		color = (0, 0, 255)
 
	# merge the channels into one image and resize the image from
	# 28x28 to 96x96 so we can better see it and then draw the
	# predicted label on the image
	image = cv2.merge([image] * 3)
	image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_LINEAR)
	cv2.putText(image, label, (5, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.75,
		color, 2)
 
	# add the image to our list of output images
	images.append(image)
# construct the montage for the images
montage = build_montages(images, (96, 96), (4, 4))[0]
 
# show the output montage
cv2_imshow( montage)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384 at 0x7F7B05A98490>
# -1

# %%
#Need to check 50/200
#epochs = 50                 # Number of Training Epochs
#num_classes = 10            # This is the number of classes in the Fashion MNIST dataset
#batch_size = 200          # This parameter can be adjusted
#img_rows, img_cols = 28, 28 # Pixel sizes of the Images in the Dataset

#Current Best
epochs = 40                 # Number of Training Epochs
num_classes = 10            # This is the number of classes in the Fashion MNIST dataset
batch_size = 300          # This parameter can be adjusted
img_rows, img_cols = 28, 28 # Pixel sizes of the Images in the Dataset

#
# This is what is known as a Tensorflow (Keras) Sequential model
# We will talk at some level about each of these layer types in class.
#

###Test####

model_1 = Sequential()
model_1.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 #kernel_initializer='he_normal',
                 input_shape=input_shape))
model_1.add(Dropout(0.7))
model_1.add(Activation('relu'))
model_1.add(Conv2D(64, kernel_size=(3,3)))
model_1.add(LeakyReLU(alpha=0.05))
model_1.add(Dropout(0.6))
model_1.add(MaxPooling2D(pool_size=(2,2)))
model_1.add(Activation('relu'))
model_1.add(Flatten())
model_1.add(Dense(1000))  
model_1.add(Activation('relu'))
model_1.add(Dropout(0.5))
model_1.add(Dense(num_classes, activation="softmax"))

my_callbacks = [ModelCheckpoint('model_out.hdf5', monitor='acc', save_best_only=True, period=1)]


#Testing Accuracy - Test: 0.9271717071533203
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
